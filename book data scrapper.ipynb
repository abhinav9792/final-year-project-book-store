# %%
from bs4 import BeautifulSoup
import requests

# %%
URL = "https://www.google.com/search?q=atomic+habit&rlz=1C1RXQR_enIN1032IN1032&tbm=shop&sxsrf=AJOqlzWIjEOYzLV7h9C0Z5KWGDUzPd_l3g:1678718891505&source=lnms&sa=X&ved=2ahUKEwixu9KZk9n9AhUJzjgGHRkkB8kQ0pQJegQIDhAE&biw=1366&bih=657&dpr=1"
r = requests.get(URL)

soup = BeautifulSoup(r.content, "lxml") # If this line causes an error, run 'pip install html5lib' or install html5lib
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-IN">
#  <head>
#   <title>
#    atomic habit - Google Shopping
#   </title>
#   <meta content="width=device-width,maximum-scale=1.0,initial-scale=1.0,minimum-scale=0.9,user-scalable=no" name="viewport"/>
#   <meta content="address=no" name="format-detection"/>
#   <meta content="email=no" name="format-detection"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <script nonce="elsWjlmAvp5T0On0Os8pcg">
#    (function(){var a=window.performance;window.start=Date.now();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,f=c.responseStart;if(f>d&&f<=window.start){window.start=f;b.wsrt=f-d;break a}}a.now&&(b.wsrt=Math.floor(a.now()))}}window.google=window.google||{};}).call(this);
#   </script>
#   <style>
#    a{color:#1a73e8;text-decoration:none}a img{border:none}body{margin:0;}html{background:#fff;font-family:Roboto,'Helvetica Neue',Arial,sans-serif;font-size:14px;color:#202124;line-height:20px;word-wrap:break-word}
# ...

# %%
soup.findAll('b', attrs = {'class':'translate-content'})
# Out:
# [<b class="translate-content">₹166.00</b>,
#  <b class="translate-content">₹369.00</b>,
#  <b class="translate-content">₹119.00</b>,
#  <b class="translate-content">₹299.00</b>,
#  <b class="translate-content">₹179.00</b>,
#  <b class="translate-content">₹265.00</b>,
#  <b class="translate-content">₹193.00</b>,
#  <b class="translate-content">₹159.00</b>,
#  <b class="translate-content">₹165.00</b>,
#  <b class="translate-content">₹148.00</b>,
#  <b class="translate-content">₹439.00</b>,
#  <b class="translate-content">₹390.00</b>,
#  <b class="translate-content">₹190.00</b>,
#  <b class="translate-content">₹278.00</b>,
#  <b class="translate-content">₹337.00</b>,
#  <b class="translate-content">₹249.00</b>,
#  <b class="translate-content">₹430.00</b>,
#  <b class="translate-content">₹165.00</b>,
#  <b class="translate-content">₹349.00</b>,
#  <b class="translate-content">₹266.00</b>,
#  <b class="translate-content">₹358.00</b>,
#  <b class="translate-content">₹309.00</b>,
# ...

# %%
soup.find('h3', attrs = {'class':'translate-content'}).text
# Out:
# '01 Atomic Habits The Life-changing Million Copy Bestseller The Life-changing'

# %%
URL = "https://www.amazon.in/Atomic-Habits-James-Clear/dp/1847941834/ref=asc_df_1847941834/?tag=googleshopdes-21&linkCode=df0&hvadid=396987849297&hvpos=&hvnetw=g&hvrand=13477747944317411864&hvpone=&hvptwo=&hvqmt=&hvdev=c&hvdvcmdl=&hvlocint=&hvlocphy=1007818&hvtargid=pla-551566274852&psc=1&ext_vrnc=hi" 
r = requests.get(URL)

soup = BeautifulSoup(r.content, "lxml") # If this line causes an error, run 'pip install html5lib' or install html5lib
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <!-- sp:end-feature:csm:head-open-part2 -->
#   <!-- sp:feature:aui-assets -->
# ...
